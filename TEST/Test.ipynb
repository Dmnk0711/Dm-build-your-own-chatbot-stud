# %%
import time

def binarySearchRecu():
    print("some usefull actions ... taking 10 sec")
    time.sleep(10) #sec
    

start= time.time()

binarySearchRecu() 

stop = time.time()

print ('Laufzeit = ' +'{:5.3f} s'.format (stop-start))
# Out:
# some usefull actions ... taking 10 sec
# Laufzeit = 10.001 s
